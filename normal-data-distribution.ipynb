# %%
import numpy
import matplotlib.pyplot as plt

x = numpy.random.normal(5.0, 1.0, 20000) # importing array by using method numpy.random.normal() with 200 values
# we set mean value 5 and standard deviation is 1
print(x)
plt.hist(x, 200)
# histogram draw with 20 bars
plt.show()
# Out:
# [5.18528273 6.52722235 4.65008167 ... 4.84351747 4.0337668  5.34949815]
